# %% [markdown]
# # Fixture cell (placeholder, not real 01.4 content)

# %% [markdown]
# # Fixture cell (placeholder, not real 01.4 content)

# %% [markdown]
# # Fixture cell (placeholder, not real 01.4 content)

# %% [markdown]
# # Fixture cell (placeholder, not real 01.4 content)

# %% [markdown]
# # Fixture cell (placeholder, not real 01.4 content)

# %% [markdown]
# # Fixture cell (placeholder, not real 01.4 content)

# %% [markdown]
# # Fixture cell (placeholder, not real 01.4 content)

# %%
# Fixture mimicking 01.4's cell 7: a display_data output whose
# text/html embeds the KMeans geometry payload (espacios/grupos/geometrias)
# with REAL values read from the committed 01.4 notebook. Regenerated
# 2026-08-09, when the clustering space stopped being a control: the block
# went from eight spaces to the single fixed one, and the canonical key
# moved from "2" to "0". The canonical geometry VALUES did not change.
# Out:
# <div id="vano-ventana-plot"><script type="text/javascript">window.PLOTLY_CONFIG = {"tipo":"vano-ventana","escala":[1,2,3],"espacios":[[false,true,"minmax"]],"grupos":["Bajo","Medio","Medio-Alto","Alto"],"colores":["rgb(252,187,161)","rgb(251,106,74)","rgb(203,24,29)","rgb(103,0,13)"],"colorSinGrupo":"#94a3b8","geometrias":{"0":{"logs":[false,true],"offset":[1.0,-3.0],"scale":[45.0,7.424386],"centroides":[[0.012823,0.406913],[0.0257,0.572701],[0.024373,0.733929],[0.237456,0.7776]]}}};</script></div>
