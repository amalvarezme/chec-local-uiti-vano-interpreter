# %% [markdown]
# # Fixture cell (placeholder, not real 01.4 content)

# %% [markdown]
# # Fixture cell (placeholder, not real 01.4 content)

# %% [markdown]
# # Fixture cell (placeholder, not real 01.4 content)

# %% [markdown]
# # Fixture cell (placeholder, not real 01.4 content)

# %% [markdown]
# # Fixture cell (placeholder, not real 01.4 content)

# %% [markdown]
# # Fixture cell (placeholder, not real 01.4 content)

# %% [markdown]
# # Fixture cell (placeholder, not real 01.4 content)

# %%
# Fixture mimicking 01.4's cell 7: a display_data output whose
# text/html embeds the KMeans geometry payload (espacios/grupos/geometrias)
# with REAL values read from the committed 01.4 notebook, 2026-08-02.
# Out:
# <div id="vano-ventana-plot"><script type="text/javascript">window.PLOTLY_CONFIG = {"tipo":"vano-ventana","escala":[1,2,3],"espacios":[[false,false,"minmax"],[false,false,"zscore"],[false,true,"minmax"],[false,true,"zscore"],[true,false,"minmax"],[true,false,"zscore"],[true,true,"minmax"],[true,true,"zscore"]],"grupos":["Bajo","Medio","Medio-Alto","Alto"],"colores":["rgb(252,187,161)","rgb(251,106,74)","rgb(203,24,29)","rgb(103,0,13)"],"colorSinGrupo":"#94a3b8","geometrias":{"0":{"logs":[false,false],"offset":[1.0,0.001],"scale":[45.0,26569.672],"centroides":[[0.013207,0.006036],[0.137546,0.013291],[0.383812,0.043374],[0.114768,0.236241]]},"1":{"logs":[false,false],"offset":[2.59487,286.292235],"scale":[3.106994,924.573328],"centroides":[[-0.326253,-0.150651],[1.421192,0.091476],[4.896774,0.682861],[1.298498,6.160968]]},"2":{"logs":[false,true],"offset":[1.0,-3.0],"scale":[45.0,7.424386],"centroides":[[0.012823,0.406913],[0.0257,0.572701],[0.024373,0.733929],[0.237456,0.7776]]},"3":{"logs":[false,true],"offset":[2.59487,1.495206],"scale":[3.106994,1.034285],"centroides":[[-0.319725,-0.929427],[-0.290267,0.64726],[1.558446,0.647053],[5.129007,1.160411]]},"4":{"logs":[true,false],"offset":[0.0,0.001],"scale":[1.662758,26569.672],"centroides":[[-0.0,0.005402],[0.181043,0.008291],[0.33194,0.01326],[0.56821,0.036566]]},"5":{"logs":[true,false],"offset":[0.256081,286.292235],"scale":[0.327264,924.573328],"centroides":[[-0.782492,-0.174816],[0.399261,-0.113909],[1.906079,0.155915],[1.3893,6.085547]]},"6":{"logs":[true,true],"offset":[0.0,-3.0],"scale":[1.662758,7.424386],"centroides":[[0.029159,0.44406],[0.240389,0.639787],[0.0,0.673257],[0.5317,0.69978]]},"7":{"logs":[true,true],"offset":[0.256081,1.495206],"scale":[0.327264,1.034285],"centroides":[[-0.672202,-1.099673],[0.672109,-0.348163],[-0.584109,0.62077],[1.651449,1.060163]]}}};</script></div>
